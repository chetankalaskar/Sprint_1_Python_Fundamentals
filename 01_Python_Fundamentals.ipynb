# %% [markdown]
# <a href="https://colab.research.google.com/github/chetankalaskar/Sprint_1_Python_Fundamentals/blob/main/01_Python_Fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Fundamentals
#
# Sprint 1 - Python Fundamentals
#
# This notebook contains my learning and practice for Python fundamentals.

# %%
name = "Chetan"
age = 25
